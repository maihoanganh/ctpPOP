# %%
using DynamicPolynomials, SparseArrays, LinearAlgebra

println("***Problem setting***")

n=5

println("Number of variable: n=",n)
println("====================")

@polyvar x[1:n]# variables

function generate_random_poly(v)
    c=2*rand(Float64,length(v)).-1
    return c'*v
end
# random quadratic objective function f
v=reverse(monomials(x,2))
f=generate_random_poly(v)


# unit sphere constraint
m=n
q=floor(Int64,n/m)
R=ones(Float64,m)./n
T=[(j-1)*q+1:j*q for j in 1:m-1]
append!(T,[(m-1)*q+1:n])

g=[R[j]-sum(x[T[j]].^2) for j in 1:m]

m=length(g)
println("Number of inequality constraints: m=",m)
println("====================")


l=0#ceil(Int64, n/7)


h=Vector{Polynomial{true,Float64}}(undef,l)
randx=[2*rand(length(T[j])).-1 for j in 1:m]# create a feasible solution
randx=[sqrt(R[j])*rand(1)[1]*randx[j]/norm(randx[j]) for j in 1:m]
randx=vcat(randx...)

for j in 1:l
    h[j]=generate_random_poly(v[2:end])
    h[j]-=h[j](x => randx) #make constraints feasible
end

l=length(h)
println("Number of equality constraints: l=",l)
println("====================")
k=2
println("Relaxed order: k=",k)
println("====================")
t=1
println("Sparse order: t=",t)
# Out:
# ***Problem setting***
# Number of variable: n=5
# ====================
# Number of inequality constraints: m=5
# ====================
# Number of equality constraints: l=1
# ====================
# Relaxed order: k=2
# ====================
# Sparse order: t=1

# %%
include("../src/ctpPOP.jl")
using .ctpPOP

opt_val=ctpPOP.POP_TS_CGAL(x,f,g,h,k,t;EigAlg="Arpack",maxit=1e10,tol=1e-3,UseEq=false)
# Out:
# WARNING: replacing module ctpPOP.
# WARNING: Compat.Printf is deprecated, use Printf instead.
#   likely near /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/solvers/ProximalBundleMethod/ProximalMethod.jl:391
# ┌ Warning: `with_optimizer` is deprecated. Adapt the following example to update your code:
# │ `with_optimizer(Ipopt.Optimizer, max_cpu_time=60.0)` becomes `optimizer_with_attributes(Ipopt.Optimizer, "max_cpu_time" => 60.0)`.
# │   caller = ip:0x0
# └ @ Core :-1
#   Computing constant trace status: OPTIMAL
#   Constant trace: ak = 3.0
#   Number of blocks: omega=12
#   Size of the largest block: s^max=16
#   Number of equality trace constraints: zeta=162
# Modeling time:
#  38.699295 seconds (51.80 M allocations: 2.546 GiB, 4.20% gc time)
# iter=1.0   val=-3.3096725088306393   gap=1.7763568394002505e-15   feas=3.380979980350555
# iter=2.0   val=-1.1032241696102132   gap=1.9372512857222832   feas=0.7312653762029772
# iter=4.0   val=-1.0710278655524248   gap=0.9574475087380456   feas=0.7159368654279901
# iter=8.0   val=-1.275979413813488   gap=0.09432956823572569   feas=0.6655626428184996
# iter=16.0   val=-0.5942969314558254   gap=0.28930700541912213   feas=0.36311882571731324
# iter=32.0   val=-0.7131382412055842   gap=0.0808371121889776   feas=0.1435960401944877
# iter=64.0   val=-0.7134876332959809   gap=0.020366202728903438   feas=0.1200199812947588
# iter=128.0   val=-0.6274259253233053   gap=0.05979673214196546   feas=0.0555391078240897
# iter=256.0   val=-0.6213012541335501   gap=0.025704747961470598   feas=0.036633059434623964
# iter=512.0   val=-0.588156903508373   gap=0.048078561167792855   feas=0.021200801043053778
# iter=1024.0   val=-0.5576627387332143   gap=0.006652944635318847   feas=0.008586149092380589
# iter=2048.0   val=-0.5485784738293968   gap=0.006839379398281498   feas=0.0032138416410969705
# iter=4096.0   val=-0.5467457409088353   gap=0.019903499616240716   feas=0.0011265813118573123
# iter=4563.0   val=-0.5464526097292578   gap=0.0008133350363561664   feas=0.000989949726521985
# tol satisfies!!!
#
# ####################################
# opt_val = -0.5464526097292578
# ####################################
# Solving time:
#   4.869380 seconds (4.46 M allocations: 340.559 MiB, 3.50% gc time)
# Total time:
#  43.635669 seconds (56.31 M allocations: 2.880 GiB, 4.12% gc time)
# -0.5464526097292578

# %%
include("../src/ctpPOP.jl")
using .ctpPOP

opt_val=ctpPOP.POP_TS_LMBM(x,f,g,h,k,t;EigAlg="Arpack",tol=1e-3,UseEq=false)
# Out:
#   Computing constant trace status: OPTIMAL
#   Constant trace: ak = 3.0
#   Number of blocks: omega=
# WARNING: replacing module ctpPOP.
# WARNING: Compat.Printf is deprecated, use Printf instead.
#   likely near /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/solvers/ProximalBundleMethod/ProximalMethod.jl:391
# 12
#   Size of the largest block: s^max=16
#   Number of equality trace constraints: zeta=162
# Modeling time:
#   0.742799 seconds (725.26 k allocations: 36.935 MiB)
# ---------------
# | Parameters: |
# ---------------
# n:       162
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
#  Warning: MC > MCU. Assigned MC = MCU.
#  Entry to LMBM:
#  NIT=    1  NFE=    1  F= 0.61044435D+00  WK= 0.4009D+00  QK= 0.2005D+00
#  NIT=    2  NFE=    2  F= 0.36607115D+00  WK= 0.3436D+00  QK= 0.2036D+00
#  NIT=    3  NFE=    3  F= 0.36607115D+00  WK= 0.2542D+00  QK= 0.1732D+00
#  NIT=    4  NFE=    4  F= 0.23105023D+00  WK= 0.4060D-01  QK= 0.6029D-01
#  NIT=    5  NFE=    5  F= 0.23105023D+00  WK= 0.2036D-01  QK= 0.2798D-01
#  NIT=    6  NFE=    6  F= 0.22988121D+00  WK= 0.5616D-01  QK= 0.1920D+00
#  NIT=    7  NFE=    7  F= 0.18354145D+00  WK= 0.4691D-01  QK= 0.1912D+00
#  Warning: A nondescent search direction occured. Restart.
#  NIT=    8  NFE=    8  F= 0.18354145D+00  WK= 0.3824D+00  QK= 0.1912D+00
#  NIT=    9  NFE=    9  F= 0.18354145D+00  WK= 0.2178D+00  QK= 0.1128D+00
#  NIT=   10  NFE=   12  F= 0.18107144D+00  WK= 0.1118D-01  QK= 0.5581D-01
#  NIT=   11  NFE=   13  F= 0.18107144D+00  WK= 0.1555D-01  QK= 0.2709D-01
#  NIT=   12  NFE=   14  F= 0.16969643D+00  WK= 0.1683D-01  QK= 0.2035D+00
#  NIT=   13  NFE=   15  F= 0.16820724D+00  WK= 0.2450D-01  QK= 0.1834D+00
#  NIT=   14  NFE=   16  F= 0.16820724D+00  WK= 0.1534D-01  QK= 0.1615D-01
#  NIT=   71  NFE=  150  F= 0.13219148D+00  WK= 0.5188D-03  QK= 0.5300D-01
#  NIT=   72  NFE=  151  F= 0.13189020D+00  WK= 0.1619D-02  QK= 0.4797D-01
#  NIT=   73  NFE=  152  F= 0.13189020D+00  WK= 0.1051D-01  QK= 0.3729D-01
#  Exit from LMBM:
#  Abnormal exit: Too many steps without significant progress.
#  NIT=   73  NFE=  164  F= 0.13188522D+00  WK= 0.1051D-01  QK= 0.3729D-01  ITERM=  2
# -----------
# | Output: |
# -----------
# Termination:     2
# N. iter.:        73
# N. func. eval.:  164
# Final value:     0.131885
# Execution time:  0.463226
#
# ####################################
# opt_val = -0.715047809309517
# ####################################
# Solving time:
#   1.024595 seconds (641.81 k allocations: 36.812 MiB)
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-0.7077928061396156, 0.5564109902344275, 1.3629737162297806, -0.7154745961357432, 0.1355544504832537]
#   check gap of lower bound  = -1.2819042942484433
#   check inequality constraint 1 = -0.3009706564229914
#   check inequality constraint 2 = -0.1095931900536562
#   check inequality constraint 3 = -1.6576973511332185
#   check inequality constraint 4 = -0.3119038977156047
#   check inequality constraint 5 = 0.18162499095418314
#   check equality constraint 1 = -0.49637455237964834
# Extracting solutuion time:
#   0.859323 seconds (850.64 k allocations: 41.924 MiB, 8.74% gc time)
# Total time:
#   2.627165 seconds (2.22 M allocations: 115.687 MiB, 2.86% gc time)
# (-0.715047809309517, Array{Float64,1}[])

# %%
using TSSOS

@time tssos_first([[f];g;h],x,k,numeq=length(h),TS="block",quotient=false);
# Out:
# ------------------------------------------------------
# The sizes of blocks:
# [16, 5]
# [1, 1]
# ------------------------------------------------------
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 86
#   Cones                  : 0
#   Scalar variables       : 22
#   Matrix variables       : 7
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 86
#   Cones                  : 0
#   Scalar variables       : 22
#   Matrix variables       : 7
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 86
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 23                conic                  : 18
# Optimizer  - Semi-definite variables: 7                 scalarized             : 226
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 3741              after factor           : 3741
# Factor     - dense dim.             : 0                 flops                  : 2.94e+05
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.8e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.00
# 1   1.2e+00  4.4e-01  2.4e-01  4.62e-01   -7.673266624e-01  -6.370434161e-01  4.4e-01  0.00
# 2   2.3e-01  8.3e-02  1.0e-02  1.74e+00   -7.324735658e-01  -6.955768041e-01  8.3e-02  0.01
# 3   6.0e-02  2.1e-02  1.5e-03  1.46e+00   -6.089923283e-01  -6.024157699e-01  2.1e-02  0.01
# 4   2.7e-02  9.6e-03  5.5e-04  7.57e-01   -5.564220890e-01  -5.535435777e-01  9.6e-03  0.01
# 5   9.6e-03  3.4e-03  1.2e-04  9.62e-01   -5.461532248e-01  -5.451745842e-01  3.4e-03  0.01
# 6   5.5e-04  1.9e-04  1.6e-06  9.80e-01   -5.466120067e-01  -5.465574826e-01  1.9e-04  0.01
# 7   8.4e-07  3.0e-07  9.6e-11  9.99e-01   -5.462488359e-01  -5.462487484e-01  3.0e-07  0.01
# 8   3.1e-08  1.1e-08  6.8e-13  1.00e+00   -5.462482033e-01  -5.462482001e-01  1.1e-08  0.01
# Optimizer terminated. Time: 0.02
#
# optimum = -0.5462482033465462
#  29.566767 seconds (36.94 M allocations: 1.810 GiB, 4.66% gc time)
