# %%
using DynamicPolynomials, SparseArrays

println("***Problem setting***")

n=50

println("Number of variable: n=",n)
println("====================")

@polyvar x[1:n]# variables

function generate_random_poly(v)
    lv=length(v)
    c=2*rand(Float64,lv).-1
    return sum(c[j]*v[j] for j in 1:lv)
end
# random quadratic objective function f
v=reverse(monomials(x,2))
f=generate_random_poly(v)


# unit sphere constraint
g=[1.0-sum(x.^2)] #type of coefficients of each polynomial must be float

m=length(g)
println("Number of inequality constraints: m=",m)
println("====================")

l=ceil(Int64, n/4)

h=Vector{Polynomial{true,Float64}}(undef,l)
randx=2*rand(n).-1# create a feasible solution
randx=rand(1)[1]*randx./sqrt(sum(randx.^2))


for j in 1:l
    h[j]=generate_random_poly(v[2:end])
    h[j]-=h[j](x => randx) #make constraints feasible
end

l=length(h)
println("Number of equality constraints: l=",l)
println("====================")

k=2

println("Relaxed order: k=",k)
println("====================")
t=1
println("Sparse order: t=",t)
# Out:
# ***Problem setting***
# Number of variable: n=50
# ====================
# Number of inequality constraints: m=1
# ====================
# Number of equality constraints: l=13
# ====================
# Relaxed order: k=2
# ====================
# Sparse order: t=1

# %%
include("../src/ctpPOP.jl")
using .ctpPOP

opt_val=ctpPOP.POP_TS_CGAL(x,f,g,h,k,t;EigAlg="Arpack",maxit=1e10,tol=1e-3,UseEq=false)
# Out:
#   Computing constant trace status: OPTIMAL
#   Constant trace: ak = 3.0
#   Number of blocks: omega=
# WARNING: replacing module ctpPOP.
# WARNING: Compat.Printf is deprecated, use Printf instead.
#   likely near /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/solvers/ProximalBundleMethod/ProximalMethod.jl:391
# 4
#   Size of the largest block: s^max=466
#   Number of equality trace constraints: zeta=72085
# Modeling time:
#  13.285126 seconds (77.11 M allocations: 15.615 GiB, 19.15% gc time)
# iter=1.0   val=-9.37741295407619   gap=5.329070518200751e-15   feas=2.8219651005185993
# iter=2.0   val=-3.125804318025397   gap=9.400670140144733   feas=0.4569120842679269
# iter=4.0   val=-3.502862980687924   gap=4.534636396371724   feas=0.5667296564275579
# iter=8.0   val=-3.388554232810457   gap=2.64509970136794   feas=0.4813860173140615
# iter=16.0   val=-3.4635501117260312   gap=1.4214261806807387   feas=0.31187936572066466
# iter=32.0   val=-2.7245113678662025   gap=1.0668494077546753   feas=0.1902036234853003
# iter=64.0   val=-2.9429995428644844   gap=0.32426083746820256   feas=0.09235507390273978
# iter=128.0   val=-2.905437752903219   gap=0.7158419713050503   feas=0.03213919657707727
# iter=256.0   val=-2.9074265263231722   gap=0.5455636049546446   feas=0.017855238257738253
# iter=512.0   val=-2.9427062003354854   gap=0.13857728151140236   feas=0.00765132177078061
# iter=1024.0   val=-2.9496128235224512   gap=0.12368664120503148   feas=0.005960992912673572
# iter=2048.0   val=-2.9676535793076915   gap=0.14622443266199525   feas=0.0030427815647028292
# iter=4096.0   val=-2.970794201362377   gap=0.07135219609284027   feas=0.0016387621289921173
# InterruptException:
#
# Stacktrace:
#  [1] Array at ./boot.jl:404 [inlined]
#  [2] Array at ./boot.jl:413 [inlined]
#  [3] Array at ./boot.jl:421 [inlined]
#  [4] similar at ./abstractarray.jl:672 [inlined]
#  [5] similar at ./abstractarray.jl:671 [inlined]
#  [6] similar at ./broadcast.jl:196 [inlined]
#  [7] copy at ./broadcast.jl:839 [inlined]
#  [8] materialize at ./broadcast.jl:819 [inlined]
#  [9] broadcast(::LinearAlgebra.var"#9#10"{typeof(+)}, ::Array{Float64,1}, ::Array{Float64,1}) at ./broadcast.jl:757
#  [10] broadcast_preserving_zero_d at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/adjtrans.jl:233 [inlined]
#  [11] + at ./arraymath.jl:39 [inlined]
#  [12] add_fast at ./fastmath.jl:261 [inlined]
#  [13] macro expansion at /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/src/pop/sparse_pop/TS/pop_TS_CGAL.jl:708 [inlined]
#  [14] macro expansion at ./simdloop.jl:77 [inlined]
#  [15] #SmallEigBlocks_TS_CGAL#574(::String, ::typeof(Main.ctpPOP.SmallEigBlocks_TS_CGAL), ::Array{LinearAlgebra.Adjoint{Float64,Array{Float64,1}},1}, ::Array{SparseMatrixCSC{Float64,UInt64},1}, ::Array{Float64,1}, ::Array{UInt64,1}, ::UInt64) at /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/src/pop/sparse_pop/TS/pop_TS_CGAL.jl:707
#  [16] #SmallEigBlocks_TS_CGAL at ./none:0 [inlined]
#  [17] #update_TS_CGAL#575(::String, ::typeof(Main.ctpPOP.update_TS_CGAL), ::Array{Float64,1}, ::Array{Float64,1}, ::Float64, ::Float64, ::Array{SparseMatrixCSC{Float64,UInt64},1}, ::Array{LinearAlgebra.Adjoint{Float64,Array{Float64,1}},1}, ::Array{UInt64,1}, ::UInt64, ::Float64, ::Float64, ::Float64) at /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/src/pop/sparse_pop/TS/pop_TS_CGAL.jl:726
#  [18] #update_TS_CGAL at ./none:0 [inlined]
#  [19] #solve_POP_TS_CGAL#580(::String, ::Float64, ::Float64, ::typeof(Main.ctpPOP.solve_POP_TS_CGAL), ::UInt64, ::Array{LinearAlgebra.Adjoint{Float64,Array{Float64,1}},1}, ::Array{SparseMatrixCSC{Float64,UInt64},1}, ::Array{UInt64,1}, ::UInt64, ::Float64, ::Float64, ::Float64) at /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/src/pop/sparse_pop/TS/pop_TS_CGAL.jl:764
#  [20] #solve_POP_TS_CGAL at ./none:0 [inlined]
#  [21] macro expansion at ./util.jl:155 [inlined]
#  [22] macro expansion at /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/src/pop/sparse_pop/TS/pop_TS_CGAL.jl:799 [inlined]
#  [23] macro expansion at ./util.jl:155 [inlined]
#  [24] #POP_TS_CGAL#581(::String, ::Float64, ::Float64, ::Bool, ::typeof(Main.ctpPOP.POP_TS_CGAL), ::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Int64) at /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/src/pop/sparse_pop/TS/pop_TS_CGAL.jl:792
#  [25] (::Main.ctpPOP.var"#kw##POP_TS_CGAL")(::NamedTuple{(:EigAlg, :maxit, :tol, :UseEq),Tuple{String,Float64,Float64,Bool}}, ::typeof(Main.ctpPOP.POP_TS_CGAL), ::Array{PolyVar{true},1}, ::Polynomial{true,Float64}, ::Array{Polynomial{true,Float64},1}, ::Array{Polynomial{true,Float64},1}, ::Int64, ::Int64) at ./none:0
#  [26] top-level scope at In[37]:3

# %%
include("../src/ctpPOP.jl")
using .ctpPOP

opt_val=ctpPOP.POP_TS_LMBM(x,f,g,h,k,t;EigAlg="Arpack",tol=1e-3,UseEq=false)
# Out:
#   Computing constant trace status: OPTIMAL
#   Constant trace: ak = 3.0
#   Number of blocks: omega=
# WARNING: replacing module ctpPOP.
# WARNING: Compat.Printf is deprecated, use Printf instead.
#   likely near /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/solvers/ProximalBundleMethod/ProximalMethod.jl:391
# 4
#   Size of the largest block: s^max=1276
#   Number of equality trace constraints: zeta=539765
# Modeling time:
# 238.837873 seconds (1.04 G allocations: 300.900 GiB, 16.02% gc time)
# ---------------
# | Parameters: |
# ---------------
# n:       539765
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
#  Warning: MC > MCU. Assigned MC = MCU.
#  Entry to LMBM:
#  NIT=    1  NFE=    1  F= 0.26005529D+00  WK= 0.2790D+00  QK= 0.1395D+00
#  NIT=    2  NFE=    2  F= 0.20357657D+00  WK= 0.1944D+00  QK= 0.1385D+00
#  NIT=    3  NFE=    3  F= 0.20357657D+00  WK= 0.1418D+00  QK= 0.1001D+00
#  NIT=    4  NFE=    4  F= 0.19015156D+00  WK= 0.5475D-01  QK= 0.1387D+00
#  NIT=    5  NFE=    5  F= 0.18844775D+00  WK= 0.3058D-01  QK= 0.5065D-01
#  NIT=    6  NFE=    6  F= 0.18443969D+00  WK= 0.1625D-01  QK= 0.1383D+00
#  NIT=    7  NFE=    7  F= 0.17104091D+00  WK= 0.1474D-01  QK= 0.1402D+00
#  NIT=    8  NFE=    8  F= 0.16051677D+00  WK= 0.1250D-01  QK= 0.5130D-01
#  NIT=    9  NFE=    9  F= 0.15956934D+00  WK= 0.7429D-02  QK= 0.1407D+00
#  NIT=   10  NFE=   10  F= 0.15215691D+00  WK= 0.2108D+01  QK= 0.1405D+00
#  NIT=   11  NFE=   11  F= 0.15215691D+00  WK= 0.2916D+00  QK= 0.2315D+00
#  NIT=   12  NFE=   22  F= 0.15214905D+00  WK= 0.1069D+00  QK= 0.1404D+00
#  Warning: A nondescent search direction occured. Restart.
#  NIT=   13  NFE=   23  F= 0.15214905D+00  WK= 0.2809D+00  QK= 0.1404D+00
#  NIT=   14  NFE=   24  F= 0.15214905D+00  WK= 0.1715D+00  QK= 0.8695D-01
#  NIT=   15  NFE=   26  F= 0.14983475D+00  WK= 0.3537D-01  QK= 0.1386D+00
#  NIT=   16  NFE=   27  F= 0.14983475D+00  WK= 0.3684D-01  QK= 0.4790D-01
#  NIT=   17  NFE=   32  F= 0.14971596D+00  WK= 0.5930D-02  QK= 0.1396D+00
#  NIT=   18  NFE=   33  F= 0.14382639D+00  WK= 0.7976D-02  QK= 0.5428D-01
#  NIT=   19  NFE=   34  F= 0.14347814D+00  WK= 0.1531D+01  QK= 0.5428D-01
#  Warning: A nondescent search direction occured. Restart.
#  NIT=   20  NFE=   35  F= 0.14347814D+00  WK= 0.1086D+00  QK= 0.5428D-01
#  NIT=   21  NFE=   36  F= 0.14347814D+00  WK= 0.7927D-01  QK= 0.3987D-01
#  NIT=   22  NFE=   45  F= 0.14339858D+00  WK= 0.1394D-03  QK= 0.1386D+00
#  NIT=   23  NFE=   46  F= 0.14321918D+00  WK= 0.1645D-03  QK= 0.5428D-01
#  NIT=   24  NFE=   48  F= 0.14321918D+00  WK= 0.3384D-01  QK= 0.3323D-01
#  NIT=   25  NFE=   53  F= 0.14286277D+00  WK= 0.3395D-01  QK= 0.1383D+00
#  NIT=   26  NFE=   54  F= 0.14286277D+00  WK= 0.2351D-01  QK= 0.9261D-01
#  NIT=   27  NFE=   57  F= 0.13967574D+00  WK= 0.3440D-02  QK= 0.1379D+00
#  NIT=   28  NFE=  102  F= 0.13967574D+00  WK= 0.2066D-01  QK= 0.1200D+00
#  NIT=   29  NFE=  147  F= 0.13967574D+00  WK= 0.1978D-01  QK= 0.1379D+00
#  NIT=   30  NFE=  192  F= 0.13967574D+00  WK= 0.1978D-01  QK= 0.1379D+00
#  NIT=   31  NFE=  237  F= 0.13967574D+00  WK= 0.1978D-01  QK= 0.1379D+00
#  NIT=   32  NFE=  282  F= 0.13967574D+00  WK= 0.1978D-01  QK= 0.1379D+00
#  NIT=   33  NFE=  327  F= 0.13967574D+00  WK= 0.1958D-01  QK= 0.1307D+00
#  NIT=   34  NFE=  332  F= 0.13842284D+00  WK= 0.1006D-01  QK= 0.1379D+00
#  NIT=   35  NFE=  333  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8363D-01
#  NIT=   36  NFE=  378  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   37  NFE=  423  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   38  NFE=  468  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   39  NFE=  513  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   40  NFE=  558  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   41  NFE=  603  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   42  NFE=  648  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   43  NFE=  693  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   44  NFE=  738  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   45  NFE=  783  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   46  NFE=  828  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   47  NFE=  873  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   48  NFE=  918  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   49  NFE=  963  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   50  NFE= 1008  F= 0.13842284D+00  WK= 0.1023D+00  QK= 0.8569D-01
#  NIT=   51  NFE= 1053  F= 0.13842284D+00  WK= 0.1019D+00  QK= 0.8255D-01
#  NIT=   52  NFE= 1098  F= 0.13842284D+00  WK= 0.1019D+00  QK= 0.8255D-01
#  NIT=   53  NFE= 1143  F= 0.13842284D+00  WK= 0.1019D+00  QK= 0.8255D-01
#  NIT=   54  NFE= 1188  F= 0.13842284D+00  WK= 0.1019D+00  QK= 0.8255D-01
#  NIT=   55  NFE= 1233  F= 0.13842284D+00  WK= 0.1019D+00  QK= 0.8255D-01
#  NIT=   56  NFE= 1278  F= 0.13842284D+00  WK= 0.9991D-01  QK= 0.7659D-01
#  NIT=   57  NFE= 1323  F= 0.13842284D+00  WK= 0.9991D-01  QK= 0.7659D-01
#  NIT=   58  NFE= 1368  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   59  NFE= 1413  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   60  NFE= 1458  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   61  NFE= 1503  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   62  NFE= 1548  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   63  NFE= 1593  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   64  NFE= 1638  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   65  NFE= 1683  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   66  NFE= 1728  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   67  NFE= 1773  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   68  NFE= 1818  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   69  NFE= 1863  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   70  NFE= 1908  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   71  NFE= 1953  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   72  NFE= 1998  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   73  NFE= 2043  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   74  NFE= 2088  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   75  NFE= 2133  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   76  NFE= 2178  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   77  NFE= 2223  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  NIT=   78  NFE= 2268  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01
#  Exit from LMBM:
#  Abnormal exit: Failure in attaining the demanded accuracy.
#  NIT=   79  NFE= 2313  F= 0.13842284D+00  WK= 0.9912D-01  QK= 0.7415D-01  ITERM= -4
# -----------
# | Output: |
# -----------
# Termination:     -4
# N. iter.:        79
# N. func. eval.:  2313
# Final value:     0.138423
# Execution time:  700.029297
#
# ####################################
# opt_val = -6.218396991566364
# ####################################
# Solving time:
# 288.941963 seconds (2.50 M allocations: 147.583 GiB, 3.31% gc time)
# Dimension of the null space of Gram matrix = 1
# ------------------------------------
# atom 1 = [-18.265719282008728, -0.35858976781420077, -0.19402359499721863, 0.2933824226749575, 0.07640051934201457, -0.32958217249911204, -0.06371687272345535, 0.14375201394192888, -0.0892818719517282, -0.35721815777659544, -0.35005662773576757, 0.089762172112851, 0.3690186066813718, -0.20895296681307682, -0.4006734944131761, 0.08326020347296954, -0.7411347532359586, -0.024145351807049346, -0.10600579083977678, -0.10842413067043963, 0.12304010396715884, 0.47849177667241294, -0.16587134746835616, 0.14027039623684961, -0.07956867597254781, -0.025093557320656337, 0.5148706918369741, 0.036445082718616024, -0.050471872504993985, 0.04056932389688034, 0.1869905464491712, -0.05843240286305009, -0.1177434877462287, 0.016979934608070263, 0.043804643866088386, 0.07728276959346704, 0.3473304118327566, 0.11451089262245832, -0.010466707779374388, -0.15000615363030248, 0.08568685718399549, 0.01511365821606163, -0.05501993863999121, -0.2515305573705615, 0.18502459471476715, 0.03207687116065824, -0.02583200282002292, -0.1136268817675832, -0.05406328607691222, 0.01024411066601745]
#   check gap of lower bound  = -28.11232181172025
#   check inequality constraint 1 = -335.12570600215383
#   check equality constraint 1 = -250.36430279538803
#   check equality constraint 2 = -157.05596095722404
#   check equality constraint 3 = -109.41177110212698
#   check equality constraint 4 = -48.87992785012428
#   check equality constraint 5 = 109.26111661037069
#   check equality constraint 6 = -278.9192850759553
#   check equality constraint 7 = -268.66121952040174
#   check equality constraint 8 = 199.1618321840767
#   check equality constraint 9 = 190.72840091624005
#   check equality constraint 10 = 40.87924796052723
#   check equality constraint 11 = 19.423002062402194
#   check equality constraint 12 = -310.49972830413196
#   check equality constraint 13 = 174.7514264026964
# Extracting solutuion time:
#   1.508708 seconds (11.81 k allocations: 113.173 MiB)
# Total time:
# 529.288945 seconds (1.04 G allocations: 448.594 GiB, 9.04% gc time)
# (-6.218396991566364, Array{Float64,1}[])

# %%
using TSSOS

@time tssos_first([[f];g;h],x,k,numeq=length(h),TS="block",quotient=false);
# Out:
# ------------------------------------------------------
# The sizes of blocks:
# [56, 10]
# [1, 1]
# ------------------------------------------------------
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 771
#   Cones                  : 0
#   Scalar variables       : 170
#   Matrix variables       : 3
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 771
#   Cones                  : 0
#   Scalar variables       : 170
#   Matrix variables       : 3
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 771
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 171               conic                  : 170
# Optimizer  - Semi-definite variables: 3                 scalarized             : 1706
# Factor     - setup time             : 0.02              dense det. time        : 0.00
# Factor     - ML order time          : 0.01              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.98e+05          after factor           : 2.98e+05
# Factor     - dense dim.             : 2                 flops                  : 1.61e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.9e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.03
# 1   3.4e-01  1.2e-01  1.8e-02  -2.44e-01  -2.359326625e+00  -2.244034547e+00  1.2e-01  0.06
# 2   1.1e-01  3.6e-02  3.3e-03  1.01e+00   -1.360579715e+00  -1.336533286e+00  3.6e-02  0.08
# 3   7.1e-03  2.4e-03  9.8e-05  1.19e+00   -1.353274859e+00  -1.352894329e+00  2.4e-03  0.10
# 4   1.2e-03  4.1e-04  6.9e-06  9.70e-01   -1.358960875e+00  -1.358895154e+00  4.1e-04  0.12
# 5   8.8e-07  3.0e-07  1.1e-10  1.00e+00   -1.359022177e+00  -1.359022059e+00  3.0e-07  0.15
# 6   1.2e-11  8.3e-12  5.4e-18  1.00e+00   -1.359022625e+00  -1.359022625e+00  4.0e-12  0.17
# Optimizer terminated. Time: 0.17
#
# optimum = -1.3590226253031958
#   0.335346 seconds (627.62 k allocations: 55.344 MiB)
