# %%
using DynamicPolynomials, SparseArrays, LinearAlgebra

println("***Problem setting***")

n=50

println("Number of variable: n=",n)
println("====================")

@polyvar x[1:n]# variables

function generate_random_poly(v)
    c=2*rand(Float64,length(v)).-1
    return c'*v
end
# random quadratic objective function f
v=reverse(monomials(x,2))
f=generate_random_poly(v)


# unit sphere constraint
m=n
q=floor(Int64,n/m)
R=ones(Float64,m)./n
T=[(j-1)*q+1:j*q for j in 1:m-1]
append!(T,[(m-1)*q+1:n])

g=[R[j]-sum(x[T[j]].^2) for j in 1:m]

m=length(g)
println("Number of inequality constraints: m=",m)
println("====================")


l=ceil(Int64, n/7)


h=Vector{Polynomial{true,Float64}}(undef,l)
randx=[2*rand(length(T[j])).-1 for j in 1:m]# create a feasible solution
randx=[sqrt(R[j])*rand(1)[1]*randx[j]/norm(randx[j]) for j in 1:m]
randx=vcat(randx...)

for j in 1:l
    h[j]=generate_random_poly(v[2:end])
    h[j]-=h[j](x => randx) #make constraints feasible
end

l=length(h)
println("Number of equality constraints: l=",l)
println("====================")
k=2
println("Relaxed order: k=",k)
println("====================")
t=1
println("Sparse order: t=",t)
# Out:
# ***Problem setting***
# Number of variable: n=50
# ====================
# Number of inequality constraints: m=50
# ====================
# Number of equality constraints: l=8
# ====================
# Relaxed order: k=2
# ====================
# Sparse order: t=1

# %%
include("../src/ctpPOP.jl")
using .ctpPOP

opt_val=ctpPOP.POP_TS_CGAL(x,f,g,h,k,t;EigAlg="Arpack",maxit=1e10,tol=1e-3,UseEq=false)
# Out:
#   Computing constant trace status: OPTIMAL
#   Constant trace: ak = 3.0000000000000013
# WARNING: replacing module ctpPOP.
# WARNING: Compat.Printf is deprecated, use Printf instead.
#   likely near /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/solvers/ProximalBundleMethod/ProximalMethod.jl:391
#   Number of blocks: omega=22
#   Size of the largest block: s^max=56
#   Number of equality trace constraints: zeta=1553
# Modeling time:
#   0.739912 seconds (1.08 M allocations: 72.583 MiB)
# iter=1.0   val=-5.05977297876238   gap=4.440892098500626e-15   feas=3.1795488391329476
# iter=2.0   val=-1.6865909929207936   gap=2.627994891897581   feas=0.7328398261513217
# iter=4.0   val=-1.75192283072717   gap=0.9839465652554964   feas=0.650434926126534
# iter=8.0   val=-1.7800695313007577   gap=0.5851951438041771   feas=0.42082181603515173
# iter=16.0   val=-1.8236244125285723   gap=0.48130971828987645   feas=0.42220731401611145
# iter=32.0   val=-1.41351014732661   gap=0.13190029745231002   feas=0.19386728555366353
# iter=64.0   val=-1.1393727047014204   gap=0.21178877525332518   feas=0.11102311698053174
# iter=128.0   val=-1.1488772770036029   gap=0.24175023152800512   feas=0.06911401979056989
# iter=256.0   val=-1.1032105807187174   gap=0.13315246416735538   feas=0.037398476825693965
# iter=512.0   val=-1.0921996386287023   gap=0.06354012859430958   feas=0.02071163055039864
# iter=1024.0   val=-1.0706478609508345   gap=0.07239372837935143   feas=0.010068170048384032
# iter=2048.0   val=-1.0657901294746885   gap=0.05186972339781226   feas=0.004072346767818366
# iter=4096.0   val=-1.066607733996971   gap=0.006218259179396668   feas=0.003070842136033344
# iter=8192.0   val=-1.0635057033360822   gap=0.0008665415016637645   feas=0.0019408806028081774
# iter=13378.0   val=-1.0554364967322512   gap=0.00046880917499803054   feas=0.0009845169042869454
# tol satisfies!!!
#
# ####################################
# opt_val = -1.0554364967322512
# ####################################
# Solving time:
#  22.145989 seconds (20.78 M allocations: 3.815 GiB, 1.89% gc time)
# Total time:
#  22.886148 seconds (21.86 M allocations: 3.886 GiB, 1.83% gc time)
# -1.0554364967322512

# %%
include("../src/ctpPOP.jl")
using .ctpPOP

opt_val=ctpPOP.POP_TS_LMBM(x,f,g,h,k,t;EigAlg="Arpack",tol=1e-3,UseEq=false)
# Out:
#   Computing constant trace status: OPTIMAL
#   Constant trace: ak = 3.0000000000000013
# WARNING: replacing module ctpPOP.
# WARNING: Compat.Printf is deprecated, use Printf instead.
#   likely near /home/hoanganh/Desktop/math-topics/ctpPOP/codes/ctpPOP/solvers/ProximalBundleMethod/ProximalMethod.jl:391
#   Number of blocks: omega=102
#   Size of the largest block: s^max=1276
#   Number of equality trace constraints: zeta=595909
# Modeling time:
# 249.709086 seconds (681.34 M allocations: 194.302 GiB, 13.02% gc time)
# ---------------
# | Parameters: |
# ---------------
# n:       595909
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
#  Warning: MC > MCU. Assigned MC = MCU.
#  Entry to LMBM:
#  NIT=    1  NFE=    1  F= 0.27166476D+00  WK= 0.2718D+00  QK= 0.1359D+00
#  NIT=    2  NFE=    2  F= 0.21988122D+00  WK= 0.1951D+00  QK= 0.1362D+00
#  NIT=    3  NFE=    3  F= 0.21988122D+00  WK= 0.1436D+00  QK= 0.1003D+00
#  NIT=    4  NFE=    5  F= 0.21765851D+00  WK= 0.3382D-01  QK= 0.1376D+00
#  NIT=    5  NFE=    6  F= 0.18384622D+00  WK= 0.9369D+02  QK= 0.1374D+00
#  NIT=    6  NFE=    7  F= 0.18384622D+00  WK= 0.5238D+00  QK= 0.2802D+00
#  NIT=    7  NFE=    9  F= 0.18317548D+00  WK= 0.1719D+00  QK= 0.1374D+00
#  Warning: A nondescent search direction occured. Restart.
#  NIT=    8  NFE=   11  F= 0.18317548D+00  WK= 0.2748D+00  QK= 0.1374D+00
#  NIT=    9  NFE=   12  F= 0.18317548D+00  WK= 0.1676D+00  QK= 0.8503D-01
#  NIT=   10  NFE=   14  F= 0.18308026D+00  WK= 0.3356D-01  QK= 0.1410D+00
#  NIT=   11  NFE=   15  F= 0.16703049D+00  WK= 0.1441D-01  QK= 0.5250D-01
#  NIT=   12  NFE=   16  F= 0.16220689D+00  WK= 0.7350D-02  QK= 0.1379D+00
#  NIT=   13  NFE=   17  F= 0.15638133D+00  WK= 0.9779D-02  QK= 0.1361D+00
#  Warning: A nondescent search direction occured. Restart.
#  NIT=   14  NFE=   18  F= 0.15638133D+00  WK= 0.2723D+00  QK= 0.1361D+00
#  NIT=   15  NFE=   19  F= 0.15638133D+00  WK= 0.1621D+00  QK= 0.8260D-01
#  NIT=   16  NFE=   22  F= 0.15592778D+00  WK= 0.1953D-01  QK= 0.1379D+00
#  NIT=   17  NFE=   23  F= 0.15592778D+00  WK= 0.3298D-01  QK= 0.5218D-01
#  NIT=   18  NFE=   26  F= 0.15272714D+00  WK= 0.7879D-02  QK= 0.1403D+00
#  NIT=   19  NFE=   27  F= 0.14996082D+00  WK= 0.6595D-02  QK= 0.5398D-01
#  NIT=   20  NFE=   28  F= 0.14465975D+00  WK= 0.7082D-02  QK= 0.1403D+00
F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.9186D-01
#  NIT=  120  NFE= 2716  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.9186D-01
#  NIT=  121  NFE= 2761  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.9186D-01
#  NIT=  122  NFE= 2806  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.9186D-01
#  NIT=  123  NFE= 2851  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.9186D-01
#  NIT=  124  NFE= 2896  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.9186D-01
#  NIT=  125  NFE= 2941  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.8809D-01
#  NIT=  126  NFE= 2986  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.8809D-01
#  NIT=  127  NFE= 3031  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.8809D-01
#  NIT=  128  NFE= 3076  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.8809D-01
#  NIT=  129  NFE= 3121  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.8809D-01
#  NIT=  130  NFE= 3166  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.8809D-01
#  NIT=  131  NFE= 3211  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.8809D-01
#  NIT=  132  NFE= 3256  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.8809D-01
#  NIT=  133  NFE= 3301  F= 0.12377955D+00  WK= 0.1155D+00  QK= 0.8809D-01
#  NIT=  134  NFE= 3314  F= 0.12375272D+00  WK= 0.1602D-02  QK= 0.1381D+00
#  NIT=  135  NFE= 3315  F= 0.12375272D+00  WK= 0.2002D-01  QK= 0.2765D-01
#  NIT=  136  NFE= 3360  F= 0.12375272D+00  WK= 0.2002D-01  QK= 0.2807D-01
#  NIT=  137  NFE= 3405  F= 0.12375272D+00  WK= 0.2000D-01  QK= 0.2467D-01
#  NIT=  138  NFE= 3450  F= 0.12375272D+00  WK= 0.2000D-01  QK= 0.2467D-01
#  NIT=  139  NFE= 3495  F= 0.12375272D+00  WK= 0.1999D-01  QK= 0.2360D-01
#  NIT=  140  NFE= 3540  F= 0.12375272D+00  WK= 0.1994D-01  QK= 0.2137D-01
#  NIT=  141  NFE= 3585  F= 0.12375272D+00  WK= 0.1994D-01  QK= 0.2137D-01
#  NIT=  142  NFE= 3630  F= 0.12375272D+00  WK= 0.1994D-01  QK= 0.2137D-01
#  NIT=  143  NFE= 3675  F= 0.12375272D+00  WK= 0.1970D-01  QK= 0.2137D-01
#  NIT=  144  NFE= 3720  F= 0.12375272D+00  WK= 0.1969D-01  QK= 0.2137D-01
#  NIT=  145  NFE= 3765  F= 0.12375272D+00  WK= 0.1969D-01  QK= 0.2137D-01
#  NIT=  146  NFE= 3810  F= 0.12375272D+00  WK= 0.1939D-01  QK= 0.1816D-01
#  NIT=  147  NFE= 3855  F= 0.12375272D+00  WK= 0.1938D-01  QK= 0.1816D-01
#  NIT=  148  NFE= 3900  F= 0.12375272D+00  WK= 0.1938D-01  QK= 0.1773D-01
#  NIT=  149  NFE= 3945  F= 0.12375272D+00  WK= 0.1938D-01  QK= 0.1773D-01
#  NIT=  150  NFE= 3990  F= 0.12375272D+00  WK= 0.1938D-01  QK= 0.1773D-01
#  NIT=  151  NFE= 4035  F= 0.12375272D+00  WK= 0.1938D-01  QK= 0.1773D-01
#  NIT=  152  NFE= 4080  F= 0.12375272D+00  WK= 0.1938D-01  QK= 0.1773D-01
#  NIT=  153  NFE= 4125  F= 0.12375272D+00  WK= 0.1938D-01  QK= 0.1773D-01
#  NIT=  154  NFE= 4170  F= 0.12375272D+00  WK= 0.1938D-01  QK= 0.1773D-01
#  NIT=  155  NFE= 4215  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1672D-01
#  NIT=  156  NFE= 4260  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1672D-01
#  NIT=  157  NFE= 4305  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1672D-01
#  NIT=  158  NFE= 4350  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  159  NFE= 4395  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  160  NFE= 4440  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  161  NFE= 4485  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  162  NFE= 4530  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  163  NFE= 4575  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  164  NFE= 4620  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  165  NFE= 4665  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  166  NFE= 4710  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  167  NFE= 4755  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  168  NFE= 4800  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  169  NFE= 4845  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  170  NFE= 4890  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  171  NFE= 4935  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  172  NFE= 4980  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  173  NFE= 5025  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  174  NFE= 5070  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  175  NFE= 5115  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  176  NFE= 5160  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  177  NFE= 5205  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  NIT=  178  NFE= 5250  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01
#  Exit from LMBM:
#  Abnormal exit: Failure in attaining the demanded accuracy.
#  NIT=  179  NFE= 5295  F= 0.12375272D+00  WK= 0.1926D-01  QK= 0.1656D-01  ITERM= -4
# -----------
# | Output: |
# -----------
# Termination:     -4
# N. iter.:        179
# N. func. eval.:  5295
# Final value:     0.123753
# Execution time:  1665.498047
#
# ####################################
# opt_val = -5.468715126246145
# ####################################
# Solving time:
# 633.081782 seconds (45.51 M allocations: 282.270 GiB, 1.94% gc time)
# Dimension of the null space of Gram matrix = 1
# Extracting solutuion time:
#   0.864869 seconds (26.86 k allocations: 123.442 MiB)
# Total time:
# 883.656176 seconds (726.88 M allocations: 476.692 GiB, 5.07% gc time)
# (-5.468715126246145, Array{Float64,1}[])

# %%
using TSSOS

@time tssos_first([[f];g;h],x,k,numeq=length(h),TS="block",quotient=false);
# Out:
# ------------------------------------------------------
# The sizes of blocks:
# [56, 10]
# [1, 1]
# ------------------------------------------------------
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 771
#   Cones                  : 0
#   Scalar variables       : 123
#   Matrix variables       : 12
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 771
#   Cones                  : 0
#   Scalar variables       : 123
#   Matrix variables       : 12
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 771
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 124               conic                  : 114
# Optimizer  - Semi-definite variables: 12                scalarized             : 2201
# Factor     - setup time             : 0.05              dense det. time        : 0.00
# Factor     - ML order time          : 0.03              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.98e+05          after factor           : 2.98e+05
# Factor     - dense dim.             : 2                 flops                  : 1.61e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   2.9e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.05
# 1   5.7e-01  2.0e-01  1.1e-01  -3.85e-01  -2.316207607e+00  -2.351173809e+00  2.0e-01  0.09
# 2   1.6e-01  5.4e-02  9.3e-03  1.34e+00   -1.339892739e+00  -1.332566217e+00  5.4e-02  0.13
# 3   2.8e-02  9.7e-03  5.6e-04  1.28e+00   -1.113232916e+00  -1.110753422e+00  9.7e-03  0.16
# 4   1.4e-02  4.7e-03  2.2e-04  7.20e-01   -1.067002364e+00  -1.065833803e+00  4.7e-03  0.20
# 5   5.8e-03  2.0e-03  6.0e-05  9.32e-01   -1.073303890e+00  -1.072791707e+00  2.0e-03  0.23
# 6   1.2e-03  4.1e-04  7.3e-06  8.46e-01   -1.058614838e+00  -1.058583907e+00  4.1e-04  0.26
# 7   5.2e-04  1.8e-04  2.0e-06  8.29e-01   -1.056932201e+00  -1.056904368e+00  1.8e-04  0.30
# 8   6.5e-05  2.2e-05  8.3e-08  9.00e-01   -1.055247845e+00  -1.055242138e+00  2.2e-05  0.33
# 9   2.9e-07  9.9e-08  2.4e-11  9.92e-01   -1.055019138e+00  -1.055019110e+00  9.9e-08  0.36
# 10  4.8e-11  5.2e-11  5.2e-17  1.00e+00   -1.055018091e+00  -1.055018091e+00  1.7e-11  0.40
# Optimizer terminated. Time: 0.40
#
# optimum = -1.0550180910598805
#   0.480809 seconds (490.02 k allocations: 44.220 MiB)
